# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import scipy
from datetime import datetime
import openweathermapy.core as owm


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Lists for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=800)
lngs = np.random.uniform(low=-180.000, high=180.000, size=800)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1])
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city.city_name)
        country_codes.append(city.country_code)
        
country_codes = [x.upper() for x in country_codes]

# Print the city count to confirm sufficient count
print(len(cities))
print(len(country_codes))
#print(cities)
# Out:
# 800
# 800

# %%
#print(country_codes)

# %%
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API url and key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

query = f"{url}appid={api_key}&units={units}&q="

#create empty lists to append necessary weather data
lat = []
long = []
temp = []
humid = []
cloud = []
wind = []
#initiate record number counter
number = 1

#begin loop through cities to get weather data from openweathermap
print("Beginning Data Retrieval")
print("-----------------------------------")

for x in range(len(cities)):
    try:
        response = requests.get(f'{query}{cities[x]},{country_codes[x].upper()}').json() 
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        number = number + 1
# print status and city name
        print(f' Processing City Record {number} of {len(cities)} complete. | {cities[x].upper()},{country_codes[x].upper()}')
# make exception for cities with no data        
    except KeyError:
        print(f'City not found. Missing data in city number {number} of {len(cities)}. | Skipping {cities[x].upper()},{country_codes[x].upper()}')
        lat.append(np.nan)
        long.append(np.nan)
        temp.append(np.nan)
        humid.append(np.nan)
        cloud.append(np.nan)
        wind.append(np.nan)
        number = number + 1

print("-----------------------------------")
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------------
#  Processing City Record 2 of 800 complete. | JAMESTOWN,SH
#  Processing City Record 3 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 4 of 800 complete. | BYRON BAY,AU
#  Processing City Record 5 of 800 complete. | BARROW,US
#  Processing City Record 6 of 800 complete. | USHUAIA,AR
# City not found. Missing data in city number 6 of 800. | Skipping ASAU,TV
#  Processing City Record 8 of 800 complete. | RINCON,US
#  Processing City Record 9 of 800 complete. | RAWSON,AR
#  Processing City Record 10 of 800 complete. | ALBANY,AU
# City not found. Missing data in city number 10 of 800. | Skipping BARENTSBURG,SJ
#  Processing City Record 12 of 800 complete. | TASIILAQ,GL
#  Processing City Record 13 of 800 complete. | RIKITEA,PF
#  Processing City Record 14 of 800 complete. | MOUNT GAMBIER,AU
# City not found. Missing data in city number 14 of 800. | Skipping LAGUNA,BR
# City not found. Missing data in city number 15 of 800. | Skipping MATAURA,PF
#  Processing City Record 17 of 800 complete. | NIKOLSKOYE,RU
#  Processing City Record 18 of 800 complete. | LONGYEARBYEN,SJ
#  Processing City Record 19 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 20 of 800 complete. | CANON CITY,US
#  Processing City Record 21 of 800 complete. | ANCUD,CL
#  Processing City Record 22 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 23 of 800 complete. | GRANDE PRAIRIE,CA
#  Processing City Record 24 of 800 complete. | KODIAK,US
#  Processing City Record 25 of 800 complete. | CAPE TOWN,ZA
#  Processing City Record 26 of 800 complete. | TODOS SANTOS,MX
#  Processing City Record 27 of 800 complete. | TASIILAQ,GL
#  Processing City Record 28 of 800 complete. | POLI,CM
#  Processing City Record 29 of 800 complete. | MOERAI,PF
#  Processing City Record 30 of 800 complete. | THOMPSON,CA
#  Processing City Record 31 of 800 complete. | FINSCHHAFEN,PG
#  Processing City Record 32 of 800 complete. | MAR DEL PLATA,AR
#  Processing City Record 33 of 800 complete. | BOA VISTA,BR
#  Processing City Record 34 of 800 complete. | CAPE TOWN,ZA
#  Processing City Record 35 of 800 complete. | SRI AMAN,MY
#  Processing City Record 36 of 800 complete. | CABO SAN LUCAS,MX
#  Processing City Record 37 of 800 complete. | PORT ELIZABETH,ZA
#  Processing City Record 38 of 800 complete. | ESPERANCE,AU
#  Processing City Record 39 of 800 complete. | TALNAKH,RU
# City not found. Missing data in city number 39 of 800. | Skipping MATAURA,PF
#  Processing City Record 41 of 800 complete. | LOMPOC,US
#  Processing City Record 42 of 800 complete. | USHUAIA,AR
#  Processing City Record 43 of 800 complete. | QAANAAQ,GL
# City not found. Missing data in city number 43 of 800. | Skipping ILLOQQORTOORMIUT,GL
#  Processing City Record 45 of 800 complete. | SHIMODA,JP
# City not found. Missing data in city number 45 of 800. | Skipping MYS SHMIDTA,RU
# City not found. Missing data in city number 46 of 800. | Skipping KAZALINSK,KZ
#  Processing City Record 48 of 800 complete. | MOUNT GAMBIER,AU
#  Processing City Record 49 of 800 complete. | ATUONA,PF
#  Processing City Record 50 of 800 complete. | ARIQUEMES,BR
# City not found. Missing data in city number 50 of 800. | Skipping NIZHNEYANSK,RU
#  Processing City Record 52 of 800 complete. | LAGOA,PT
# City not found. Missing data in city number 52 of 800. | Skipping MATAURA,PF
#  Processing City Record 54 of 800 complete. | BANEPA,NP
# City not found. Missing data in city number 54 of 800. | Skipping ASFI,MA
#  Processing City Record 56 of 800 complete. | PISCO,PE
#  Processing City Record 57 of 800 complete. | CARNARVON,AU
#  Processing City Record 58 of 800 complete. | DIKSON,RU
#  Processing City Record 59 of 800 complete. | MAHEBOURG,MU
#  Processing City Record 60 of 800 complete. | BUTA,CD
#  Processing City Record 61 of 800 complete. | RIKITEA,PF
#  Processing City Record 62 of 800 complete. | MEULABOH,ID
# City not found. Missing data in city number 62 of 800. | Skipping KARAUZYAK,UZ
#  Processing City Record 64 of 800 complete. | RIKITEA,PF
#  Processing City Record 65 of 800 complete. | DONGYING,CN
#  Processing City Record 66 of 800 complete. | BREDASDORP,ZA
#  Processing City Record 67 of 800 complete. | AQUIRAZ,BR
#  Processing City Record 68 of 800 complete. | COCKBURN TOWN,TC
#  Processing City Record 69 of 800 complete. | SAINT-JOSEPH,RE
#  Processing City Record 70 of 800 complete. | NEW NORFOLK,AU
#  Processing City Record 71 of 800 complete. | VAINI,TO
#  Processing City Record 72 of 800 complete. | BOSASO,SO
# City not found. Missing data in city number 72 of 800. | Skipping NIZHNEYANSK,RU
#  Processing City Record 74 of 800 complete. | CABO SAN LUCAS,MX
# City not found. Missing data in city number 74 of 800. | Skipping MATAURA,PF
#  Processing City Record 76 of 800 complete. | CAPE TOWN,ZA
#  Processing City Record 77 of 800 complete. | NORTH BEND,US
#  Processing City Record 78 of 800 complete. | SEVERO-KURILSK,RU
#  Processing City Record 79 of 800 complete. | SABANG,ID
# City not found. Missing data in city number 79 of 800. | Skipping BARENTSBURG,SJ
# City not found. Missing data in city number 80 of 800. | Skipping BENGKULU,ID
#  Processing City Record 82 of 800 complete. | YELLOWKNIFE,CA
#  Processing City Record 83 of 800 complete. | ULLADULLA,AU
#  Processing City Record 84 of 800 complete. | ROCHA,UY
#  Processing City Record 85 of 800 complete. | USHUAIA,AR
#  Processing City Record 86 of 800 complete. | HAY RIVER,CA
#  Processing City Record 87 of 800 complete. | HERMANUS,ZA
#  Processing City Record 88 of 800 complete. | BERLEVAG,NO
#  Processing City Record 89 of 800 complete. | NEW NORFOLK,AU
#  Processing City Record 90 of 800 complete. | SEMINOLE,US
#  Processing City Record 91 of 800 complete. | BLUFF,NZ
#  Processing City Record 92 of 800 complete. | USHUAIA,AR
#  Processing City Record 93 of 800 complete. | ARRAIAL DO CABO,BR
#  Processing City Record 94 of 800 complete. | USHUAIA,AR
# City not found. Missing data in city number 94 of 800. | Skipping OBLUCHE,RU
#  Processing City Record 96 of 800 complete. | TURA,RU
#  Processing City Record 97 of 800 complete. | CHUY,UY
#  Processing City Record 98 of 800 complete. | CAPE TOWN,ZA
#  Processing City Record 99 of 800 complete. | JAMESTOWN,SH
#  Processing City Record 100 of 800 complete. | HOBART,AU
#  Processing City Record 101 of 800 complete. | BELYY YAR,RU
#  Processing City Record 102 of 800 complete. | USHUAIA,AR
#  Processing City Record 103 of 800 complete. | SAINT-PHILIPPE,RE
#  Processing City Record 104 of 800 complete. | PANGODY,RU
# City not found. Missing data in city number 104 of 800. | Skipping GAT,LY
#  Processing City Record 106 of 800 complete. | KAPAA,US
# City not found. Missing data in city number 106 of 800. | Skipping TAOLANARO,MG
#  Processing City Record 108 of 800 complete. | HERMANUS,ZA
#  Processing City Record 109 of 800 complete. | ARMAN,RU
# City not found. Missing data in city number 109 of 800. | Skipping MATAURA,PF
#  Processing City Record 111 of 800 complete. | BELAYA GORA,RU
#  Processing City Record 112 of 800 complete. | HILO,US
#  Processing City Record 113 of 800 complete. | AHUIMANU,US
#  Processing City Record 114 of 800 complete. | BROOME,AU
#  Processing City Record 115 of 800 complete. | ALBANY,AU
#  Processing City Record 116 of 800 complete. | GUBKINSKIY,RU
#  Processing City Record 117 of 800 complete. | BANDARBEYLA,SO
# City not found. Missing data in city number 117 of 800. | Skipping BARENTSBURG,SJ
#  Processing City Record 119 of 800 complete. | NEW NORFOLK,AU
#  Processing City Record 120 of 800 complete. | ALBANY,AU
# City not found. Missing data in city number 120 of 800. | Skipping TAOLANARO,MG
#  Processing City Record 122 of 800 complete. | BROWNSVILLE,US
#  Processing City Record 123 of 800 complete. | RIO GALLEGOS,AR
#  Processing City Record 124 of 800 complete. | CLYDE RIVER,CA
#  Processing City Record 125 of 800 complete. | SAN ANDRES,CO
#  Processing City Record 126 of 800 complete. | TIKSI,RU
#  Processing City Record 127 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 128 of 800 complete. | BUSSELTON,AU
#  Processing City Record 129 of 800 complete. | USHUAIA,AR
#  Processing City Record 130 of 800 complete. | LONGYEARBYEN,SJ
#  Processing City Record 131 of 800 complete. | PORTLAND,AU
#  Processing City Record 132 of 800 complete. | QAANAAQ,GL
#  Processing City Record 133 of 800 complete. | RIKITEA,PF
#  Processing City Record 134 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 135 of 800 complete. | GUERRERO NEGRO,MX
# City not found. Missing data in city number 135 of 800. | Skipping YINGZHONG,CN
#  Processing City Record 137 of 800 complete. | CARAVELAS,BR
#  Processing City Record 138 of 800 complete. | DUBAI,AE
#  Processing City Record 139 of 800 complete. | MONTLUCON,FR
#  Processing City Record 140 of 800 complete. | PANGAI,TO
#  Processing City Record 141 of 800 complete. | TAHLEQUAH,US
#  Processing City Record 142 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 143 of 800 complete. | ALBANY,AU
#  Processing City Record 144 of 800 complete. | GEORGETOWN,SH
#  Processing City Record 145 of 800 complete. | LEBU,CL
#  Processing City Record 146 of 800 complete. | BUTARITARI,KI
#  Processing City Record 147 of 800 complete. | BREDASDORP,ZA
#  Processing City Record 148 of 800 complete. | HERMANUS,ZA
# City not found. Missing data in city number 148 of 800. | Skipping MATAURA,PF
#  Processing City Record 150 of 800 complete. | MARABBA,SD
#  Processing City Record 151 of 800 complete. | HITHADHOO,MV
# City not found. Missing data in city number 151 of 800. | Skipping GEZING,IN
#  Processing City Record 153 of 800 complete. | RIKITEA,PF
#  Processing City Record 154 of 800 complete. | PUNTA ARENAS,CL
# City not found. Missing data in city number 154 of 800. | Skipping ILLOQQORTOORMIUT,GL
#  Processing City Record 156 of 800 complete. | DEPUTATSKIY,RU
#  Processing City Record 157 of 800 complete. | BETHEL,US
#  Processing City Record 158 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 159 of 800 complete. | TALAYA,RU
#  Processing City Record 160 of 800 complete. | ROMA,AU
# City not found. Missing data in city number 160 of 800. | Skipping MILINGIMBI,AU
#  Processing City Record 162 of 800 complete. | NAMATANAI,PG
#  Processing City Record 163 of 800 complete. | PROVIDENIYA,RU
#  Processing City Record 164 of 800 complete. | QAANAAQ,GL
#  Processing City Record 165 of 800 complete. | PEVEK,RU
#  Processing City Record 166 of 800 complete. | SAO JOAO DA BARRA,BR
#  Processing City Record 167 of 800 complete. | HERMANUS,ZA
# City not found. Missing data in city number 167 of 800. | Skipping TUMANNYY,RU
#  Processing City Record 169 of 800 complete. | HUSAVIK,IS
#  Processing City Record 170 of 800 complete. | BREDASDORP,ZA
#  Processing City Record 171 of 800 complete. | BETHEL,US
#  Processing City Record 172 of 800 complete. | PUERTO AYORA,EC
#  Processing City Record 173 of 800 complete. | CIDREIRA,BR
#  Processing City Record 174 of 800 complete. | NIJAR,ES
#  Processing City Record 175 of 800 complete. | CAPE TOWN,ZA
#  Processing City Record 176 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 177 of 800 complete. | KYSHTOVKA,RU
#  Processing City Record 178 of 800 complete. | OISTINS,BB
#  Processing City Record 179 of 800 complete. | AUKI,SB
#  Processing City Record 180 of 800 complete. | RIKITEA,PF
#  Processing City Record 181 of 800 complete. | HILO,US
#  Processing City Record 182 of 800 complete. | RIO GALLEGOS,AR
# City not found. Missing data in city number 182 of 800. | Skipping YELETSKIY,RU
# City not found. Missing data in city number 183 of 800. | Skipping ILLOQQORTOORMIUT,GL
#  Processing City Record 185 of 800 complete. | KODIAK,US
#  Processing City Record 186 of 800 complete. | USOGORSK,RU
#  Processing City Record 187 of 800 complete. | SAINT-PHILIPPE,RE
# City not found. Missing data in city number 187 of 800. | Skipping AIRAI,PW
#  Processing City Record 189 of 800 complete. | PUNTA ARENAS,CL
#  Processing City Record 190 of 800 complete. | BUSSELTON,AU
#  Processing City Record 191 of 800 complete. | VAINI,TO
#  Processing City Record 192 of 800 complete. | SOLNECHNYY,RU
#  Processing City Record 193 of 800 complete. | PORT ELIZABETH,ZA
#  Processing City Record 194 of 800 complete. | THOMPSON,CA
#  Processing City Record 195 of 800 complete. | RIBEIRA BRAVA,PT
#  Processing City Record 196 of 800 complete. | ALBANY,AU
#  Processing City Record 197 of 800 complete. | MAR DEL PLATA,AR
#  Processing City Record 198 of 800 complete. | UST-MAYA,RU
#  Processing City Record 199 of 800 complete. | NANTUCKET,US
#  Processing City Record 200 of 800 complete. | NAMATANAI,PG
#  Processing City Record 201 of 800 complete. | TE ANAU,NZ
#  Processing City Record 202 of 800 complete. | BUSSELTON,AU
#  Processing City Record 203 of 800 complete. | SAO JOAO DA BARRA,BR
#  Processing City Record 204 of 800 complete. | ATUONA,PF
#  Processing City Record 205 of 800 complete. | CHERNYSHEVSKIY,RU
#  Processing City Record 206 of 800 complete. | KANGAATSIAQ,GL
#  Processing City Record 207 of 800 complete. | KAPAA,US
#  Processing City Record 208 of 800 complete. | MAR DEL PLATA,AR
#  Processing City Record 209 of 800 complete. | VYGONICHI,RU
#  Processing City Record 210 of 800 complete. | ALIBAG,IN
#  Processing City Record 211 of 800 complete. | RIKITEA,PF
#  Processing City Record 212 of 800 complete. | WAINGAPU,ID
# City not found. Missing data in city number 212 of 800. | Skipping MYS SHMIDTA,RU
#  Processing City Record 214 of 800 complete. | DIKSON,RU
#  Processing City Record 215 of 800 complete. | BATHSHEBA,BB
#  Processing City Record 216 of 800 complete. | PAAMIUT,GL
#  Processing City Record 217 of 800 complete. | BUSSELTON,AU
#  Processing City Record 218 of 800 complete. | MOUNT PLEASANT,US
#  Processing City Record 219 of 800 complete. | BUTARITARI,KI
#  Processing City Record 220 of 800 complete. | KAPAA,US
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# //anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# //anaconda3/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# //anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# //anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# //anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# //anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# //anaconda3/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# //anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# //anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-24a268b653fb> in <module>
#      21 for x in range(len(cities)):
#      22     try:
# ---> 23         response = requests.get(f'{query}{cities[x]},{country_codes[x].upper()}').json()
#      24         lat.append(response['coord']['lat'])
#      25         long.append(response['coord']['lon'])
#
# //anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# //anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# //anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#convert data to DataFrame
weather_df = pd.DataFrame({"City": cities,
                           "Country": country_codes,
                           "Latitude": lat,
                           "Longitude": long,
                           "Temperature": temp,
                           "Humidity": humid,
                           "Cloudiness": cloud,
                           "Wind Speed": wind,
                          })
#drop NaN values for cities not found
weather_df = weather_df.dropna(how='any')
print(f"The data frame contains {len(weather_df['City'])} unique cities.")
      
#Save dataframe as csv
pd.DataFrame.to_csv(weather_df, 'city_weather_data.csv')

#display DataFrame
weather_df.head(10)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Temperature'], marker="8", s=weather_df['Temperature'], facecolors="yellow", edgecolors="gray")

#labeling and formatting
plt.title(f'City Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.savefig('Lat_Temp.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Humidity'], marker="|", s=weather_df['Humidity'], facecolors="black", edgecolors="gray")

#labeling and formatting
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

plt.savefig('lat_humidity.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'], marker="o", s=weather_df['Cloudiness'], facecolors="white", edgecolors="gray")

#labeling and formatting
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)

plt.savefig('lat_cloud.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'], marker="4", s=weather_df['Wind Speed'], facecolors="gray", edgecolors="black")

#labeling and formatting
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_wind.png', bbox_inches='tight')
